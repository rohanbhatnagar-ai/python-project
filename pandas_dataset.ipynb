# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# load the datasets
df = pd.read_csv("C:\\Users\\ntt\\Downloads\\books.csv")
df
# Out:
#        bookID                                              title  \
# 0           1  Harry Potter and the Half-Blood Prince (Harry ...
# 1           2  Harry Potter and the Order of the Phoenix (Har...
# 2           4  Harry Potter and the Chamber of Secrets (Harry...
# 3           5  Harry Potter and the Prisoner of Azkaban (Harr...
# 4           8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
# ...       ...                                                ...
# 11122   45631   Expelled from Eden: A William T. Vollmann Reader
# 11123   45633                        You Bright and Risen Angels
# 11124   45634                    The Ice-Shirt (Seven Dreams #1)
# 11125   45639                                        Poor People
# 11126   45641                        Las aventuras de Tom Sawyer
#
#                                                  authors average_rating  \
# 0                             J.K. Rowling/Mary GrandPré           4.57
# ...

# %%
df.shape
# Out:
# (11127, 13)

# %%
df.head(5)
# Out:
#    bookID                                              title  \
# 0       1  Harry Potter and the Half-Blood Prince (Harry ...
# 1       2  Harry Potter and the Order of the Phoenix (Har...
# 2       4  Harry Potter and the Chamber of Secrets (Harry...
# 3       5  Harry Potter and the Prisoner of Azkaban (Harr...
# 4       8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
#
#                       authors average_rating        isbn       isbn13  \
# 0  J.K. Rowling/Mary GrandPré           4.57   439785960  9.78044E+12
# 1  J.K. Rowling/Mary GrandPré           4.49   439358078  9.78044E+12
# 2                J.K. Rowling           4.42   439554896  9.78044E+12
# 3  J.K. Rowling/Mary GrandPré           4.56  043965548X  9.78044E+12
# 4  J.K. Rowling/Mary GrandPré           4.78   439682584  9.78044E+12
#
#   language_code   num_pages  ratings_count  text_reviews_count  \
# 0           eng         652        2095690               27591
# ...

# %%
df.tail(6)
# Out:
#        bookID                                             title  \
# 11121   45630                                 Whores for Gloria
# 11122   45631  Expelled from Eden: A William T. Vollmann Reader
# 11123   45633                       You Bright and Risen Angels
# 11124   45634                   The Ice-Shirt (Seven Dreams #1)
# 11125   45639                                       Poor People
# 11126   45641                       Las aventuras de Tom Sawyer
#
#                                                  authors average_rating  \
# 11121                                William T. Vollmann           3.69
# 11122  William T. Vollmann/Larry McCaffery/Michael He...           4.06
# 11123                                William T. Vollmann           4.08
# 11124                                William T. Vollmann           3.96
# 11125                                William T. Vollmann           3.72
# 11126                                         Mark Twain           3.91
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11127 entries, 0 to 11126
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   bookID              11127 non-null  int64
#  1   title               11127 non-null  object
#  2   authors             11127 non-null  object
#  3   average_rating      11127 non-null  object
#  4   isbn                11127 non-null  object
#  5   isbn13              11127 non-null  object
#  6   language_code       11127 non-null  object
#  7     num_pages         11127 non-null  object
#  8   ratings_count       11127 non-null  int64
#  9   text_reviews_count  11127 non-null  int64
#  10  publication_date    11127 non-null  object
#  11  publisher           11127 non-null  object
#  12  Unnamed: 12         4 non-null      object
# dtypes: int64(3), object(10)
# memory usage: 1.1+ MB

# %%
df.describe()
# Out:
#              bookID  ratings_count  text_reviews_count
# count  11127.000000   1.112700e+04        11127.000000
# mean   21310.938887   1.793649e+04          541.864474
# std    13093.358023   1.124794e+05         2576.174610
# min        1.000000   0.000000e+00            0.000000
# 25%    10287.000000   1.040000e+02            9.000000
# 50%    20287.000000   7.450000e+02           47.000000
# 75%    32104.500000   4.993500e+03          237.500000
# max    45641.000000   4.597666e+06        94265.000000

# %%
df.isnull().sum()
# Out:
# bookID                    0
# title                     0
# authors                   0
# average_rating            0
# isbn                      0
# isbn13                    0
# language_code             0
#   num_pages               0
# ratings_count             0
# text_reviews_count        0
# publication_date          0
# publisher                 0
# Unnamed: 12           11123
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# remove unnecssary columns
df.drop(columns=["Unnamed: 12"], inplace = True)

# %%
df.columns
# Out:
# Index(['bookID', 'title', 'authors', 'average_rating', 'isbn', 'isbn13',
#        'language_code', '  num_pages', 'ratings_count', 'text_reviews_count',
#        'publication_date', 'publisher'],
#       dtype='object')

# %%
# remove the duplicates rowes
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# checking the missing value
df.isnull().sum()
# Out:
# bookID                0
# title                 0
# authors               0
# average_rating        4
# isbn                  0
# isbn13                0
# language_code         0
#   num_pages           4
# ratings_count         0
# text_reviews_count    0
# publication_date      6
# publisher             0
# dtype: int64

# %%
# fix datatypes
df["average_rating"] =pd.to_numeric(df["average_rating"], errors ="coerce")
df["  num_pages"] = pd.to_numeric(df["  num_pages"], errors = "coerce")

# %%
# clean dates
df["publication_date"] =pd.to_datetime(df["publication_date"], errors = "coerce")

# %%
# extract the year
df["publication_date"] = df["publication_date"].dt.year

# %%
# clean text
df["authors"] = df["authors"].str.strip()
df["publisher"] = df["publisher"].str.strip()

# %%
df["average_rating"].describe()
# Out:
# count    11123.000000
# mean         3.934075
# std          0.350485
# min          0.000000
# 25%          3.770000
# 50%          3.960000
# 75%          4.140000
# max          5.000000
# Name: average_rating, dtype: float64

# %%
df.isnull().sum()
# Out:
# bookID                0
# title                 0
# authors               0
# average_rating        4
# isbn                  0
# isbn13                0
# language_code         0
#   num_pages           4
# ratings_count         0
# text_reviews_count    0
# publication_date      6
# publisher             0
# dtype: int64

# %%
df["average_rating"] = df["average_rating"].ffill().bfill()

# %%
df.isna().sum()
# Out:
# bookID                0
# title                 0
# authors               0
# average_rating        0
# isbn                  0
# isbn13                0
# language_code         0
#   num_pages           4
# ratings_count         0
# text_reviews_count    0
# publication_date      6
# publisher             0
# dtype: int64

# %%
df["publication_date"] = df["publication_date"].ffill().bfill()

# %%
df.isna().sum()
# Out:
# bookID                0
# title                 0
# authors               0
# average_rating        0
# isbn                  0
# isbn13                0
# language_code         0
#   num_pages           4
# ratings_count         0
# text_reviews_count    0
# publication_date      0
# publisher             0
# dtype: int64

# %%
df["  num_pages"] = df["  num_pages"].ffill().bfill()

# %%
df.isnull().sum()
# Out:
# bookID                0
# title                 0
# authors               0
# average_rating        0
# isbn                  0
# isbn13                0
# language_code         0
#   num_pages           0
# ratings_count         0
# text_reviews_count    0
# publication_date      0
# publisher             0
# dtype: int64

# %%
df["isbn13"].min()
# Out:
# '156384155X'

# %%
df
# Out:
#        bookID                                              title  \
# 0           1  Harry Potter and the Half-Blood Prince (Harry ...
# 1           2  Harry Potter and the Order of the Phoenix (Har...
# 2           4  Harry Potter and the Chamber of Secrets (Harry...
# 3           5  Harry Potter and the Prisoner of Azkaban (Harr...
# 4           8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
# ...       ...                                                ...
# 11122   45631   Expelled from Eden: A William T. Vollmann Reader
# 11123   45633                        You Bright and Risen Angels
# 11124   45634                    The Ice-Shirt (Seven Dreams #1)
# 11125   45639                                        Poor People
# 11126   45641                        Las aventuras de Tom Sawyer
#
#                                                  authors  average_rating  \
# 0                             J.K. Rowling/Mary GrandPré            4.57
# ...

# %%
df.sort_values("average_rating", ascending=False)[
    ["title", "authors", "average_rating"]
].head(10)
# Out:
#                                                    title  \
# 5478   The Goon Show  Volume 11: He's Fallen in the W...
# 9724       The Irish Anatomist: A Study of Flann O'Brien
# 9851   The American Campaign: U.S. Presidential Campa...
# 4935   Bulgakov's the Master and Margarita: The Text ...
# 9897   His Princess Devotional: A Royal Encounter Wit...
# 5025   The Complete Theory Fun Factory: Music Theory ...
# 1243   Middlesex Borough (Images of America: New Jersey)
# 10266         Bill Gates: Computer Legend (Famous Lives)
# 5476   The Goon Show  Volume 4: My Knees Have Fallen ...
# 8547        Fanning the Flame: Bible  Cross  and Mission
#
#                                                 authors  average_rating
# 5478                                         NOT A BOOK             5.0
# 9724                                      Keith Donohue             5.0
# 9851                                  James E. Campbell             5.0
# ...

# %%
df.sort_values("ratings_count", ascending=False)[
    ["title", "authors", "ratings_count"]
].head(10)
# Out:
#                                                    title  \
# 10340                            Twilight (Twilight  #1)
# 1697                 The Hobbit  or There and Back Again
# 1462                              The Catcher in the Rye
# 307                 Angels & Demons (Robert Langdon  #1)
# 3      Harry Potter and the Prisoner of Azkaban (Harr...
# 4416   Harry Potter and the Chamber of Secrets (Harry...
# 1      Harry Potter and the Order of the Phoenix (Har...
# 23     The Fellowship of the Ring (The Lord of the Ri...
# 2114                                         Animal Farm
# 0      Harry Potter and the Half-Blood Prince (Harry ...
#
#                                        authors  ratings_count
# 10340                          Stephenie Meyer        4597666
# 1697                            J.R.R. Tolkien        2530894
# 1462                             J.D. Salinger        2457092
# 307                                  Dan Brown        2418736
# ...

# %%
df.sort_values("text_reviews_count", ascending=False)[
    ["title", "authors", "text_reviews_count"]
].head(10)
# Out:
#                                                    title  \
# 10340                            Twilight (Twilight  #1)
# 5272                                      The Book Thief
# 1069                           The Giver (The Giver  #1)
# 284                                        The Alchemist
# 10704                                Water for Elephants
# 7312   The Lightning Thief (Percy Jackson and the Oly...
# 5409                                     Eat  Pray  Love
# 2060                                    The Glass Castle
# 1462                              The Catcher in the Rye
# 3      Harry Potter and the Prisoner of Azkaban (Harr...
#
#                                         authors  text_reviews_count
# 10340                           Stephenie Meyer               94265
# 5272          Markus Zusak/Cao Xuân Việt Khương               86881
# 1069                                 Lois Lowry               56604
# ...

# %%
df["average_rating"].corr(df["ratings_count"])
# Out:
# np.float64(0.038225085395334736)

# %%
import matplotlib.pyplot as plt

plt.scatter(df["ratings_count"], df["average_rating"])
plt.xlabel("Number of Ratings")
plt.ylabel("Average Rating")
plt.title("Ratings Count vs Average Rating")
plt.show()

# %%
df["language_code"].value_counts()
# Out:
# language_code
# eng            8908
# en-US          1408
# spa             218
# en-GB           214
# fre             144
# ger              99
# jpn              46
# mul              19
# zho              14
# grc              11
# por              10
# en-CA             7
# ita               5
# lat               3
# enm               3
# rus               2
# swe               2
# ara               1
# wel               1
# gla               1
# tur               1
# 9.78085E+12       1
# nor               1
# 9.78156E+12       1
# glg               1
# msa               1
# nl                1
# 9.78159E+12       1
# 9.78067E+12       1
# srp               1
# ale               1
# Name: count, dtype: int64

# %%
df["publisher"].value_counts().head(10)
# Out:
# publisher
# Vintage             318
# Penguin Books       261
# Penguin Classics    184
# Mariner Books       150
# Ballantine Books    144
# Harper Perennial    112
# HarperCollins       112
# Pocket Books        111
# Bantam              110
# VIZ Media LLC        88
# Name: count, dtype: int64

# %%
df["average_rating"].mean()
# Out:
# np.float64(3.9340666846409635)

# %%
df["average_rating"].median()
# Out:
# 3.96

# %%
df.to_csv("cleaned_books.csv", index=False)
